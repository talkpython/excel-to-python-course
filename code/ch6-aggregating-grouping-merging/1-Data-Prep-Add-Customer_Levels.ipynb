# %% [markdown]
# ## Example of merging data with pandas

# %%
import pandas as pd
from pathlib import Path

# %%
input_file = Path.cwd() / 'data' / 'raw' / 'sample_sales.xlsx'
level_file = Path.cwd() / 'data' / 'raw' / 'customer_levels.xlsx'
extra_transactions = Path.cwd() / 'data' / 'raw' / 'sample_sales_50_extra.xlsx'

# %%
sales = pd.read_excel(input_file)
levels = pd.read_excel(level_file)
extra_sales = pd.read_excel(extra_transactions)

# %%
sales.head()
# Out:
#      invoice   company purchase_date product  quantity  price  extended amount
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17              323
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14              420
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23              161
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29              203
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19              684

# %%
sales.shape
# Out:
# (1000, 7)

# %%
levels.head()
# Out:
#   Company Name     level
# 0        Abatz   diamond
# 1        Agivu    silver
# 2        Aibox  platinum
# 3       Ailane    silver
# 4        Aimbo   diamond

# %%
levels.shape
# Out:
# (351, 2)

# %%
extra_sales.shape
# Out:
# (50, 7)

# %%
extra_sales.head()
# Out:
#       invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-293  Linkbuzz    2019-01-28   shirt        28     17
# 1  JQ-501-633     Aimbu    2019-10-04    book        21     14
# 2  FI-165-583   Dablist    2019-05-05  poster         4     23
# 3  XP-005-553   Rhycero    2019-11-03     pen        49     29
# 4  NB-917-183   Skinder    2019-07-17  poster        18     19
#
#    extended amount
# 0              476
# 1              294
# 2               92
# 3             1421
# 4              342

# %%
pd.concat([sales, extra_sales])
# Out:
#        invoice      company purchase_date product  quantity  price  \
# 0    ZN-870-29     Realcube    2019-03-05   shirt        19     17
# 1    JQ-501-63        Zooxo    2019-07-09    book        30     14
# 2    FI-165-58      Dabtype    2019-08-12  poster         7     23
# 3    XP-005-55     Skipfire    2019-11-18     pen         7     29
# 4    NB-917-18     Bluezoom    2019-04-18  poster        36     19
# ..         ...          ...           ...     ...       ...    ...
# 45  PS-680-563        Quimm    2019-09-19  poster         0     35
# 46  MU-441-943       Podcat    2019-09-15   shirt         7     15
# 47  RR-924-583       Oyoloo    2019-12-24    book        17     10
# 48  NM-907-403  Thoughtbeat    2019-08-02  poster         8     26
# 49  CC-124-201  Thoughtblab    2019-06-30  poster        23      5
#
#     extended amount
# 0               323
# 1               420
# 2               161
# 3               203
# 4               684
# ..              ...
# 45                0
# 46              105
# 47              170
# 48              208
# 49              115
#
# [1050 rows x 7 columns]

# %%
sales.append(extra_sales)
# Out:
#        invoice      company purchase_date product  quantity  price  \
# 0    ZN-870-29     Realcube    2019-03-05   shirt        19     17
# 1    JQ-501-63        Zooxo    2019-07-09    book        30     14
# 2    FI-165-58      Dabtype    2019-08-12  poster         7     23
# 3    XP-005-55     Skipfire    2019-11-18     pen         7     29
# 4    NB-917-18     Bluezoom    2019-04-18  poster        36     19
# ..         ...          ...           ...     ...       ...    ...
# 45  PS-680-563        Quimm    2019-09-19  poster         0     35
# 46  MU-441-943       Podcat    2019-09-15   shirt         7     15
# 47  RR-924-583       Oyoloo    2019-12-24    book        17     10
# 48  NM-907-403  Thoughtbeat    2019-08-02  poster         8     26
# 49  CC-124-201  Thoughtblab    2019-06-30  poster        23      5
#
#     extended amount
# 0               323
# 1               420
# 2               161
# 3               203
# 4               684
# ..              ...
# 45                0
# 46              105
# 47              170
# 48              208
# 49              115
#
# [1050 rows x 7 columns]

# %%
all_sales = pd.concat([sales, extra_sales])

# %%
all_sales.shape
# Out:
# (1050, 7)

# %%
all_sales.head()
# Out:
#      invoice   company purchase_date product  quantity  price  extended amount
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17              323
# 1  JQ-501-63     Zooxo    2019-07-09    book        30     14              420
# 2  FI-165-58   Dabtype    2019-08-12  poster         7     23              161
# 3  XP-005-55  Skipfire    2019-11-18     pen         7     29              203
# 4  NB-917-18  Bluezoom    2019-04-18  poster        36     19              684

# %%
# This will give an error
#pd.merge(all_sales, levels)

# %%
pd.merge(all_sales, levels, left_on='company', right_on='Company Name', how='left')
# Out:
#          invoice      company purchase_date product  quantity  price  \
# 0      ZN-870-29     Realcube    2019-03-05   shirt        19     17
# 1      JQ-501-63        Zooxo    2019-07-09    book        30     14
# 2      FI-165-58      Dabtype    2019-08-12  poster         7     23
# 3      XP-005-55     Skipfire    2019-11-18     pen         7     29
# 4      NB-917-18     Bluezoom    2019-04-18  poster        36     19
# ...          ...          ...           ...     ...       ...    ...
# 1045  PS-680-563        Quimm    2019-09-19  poster         0     35
# 1046  MU-441-943       Podcat    2019-09-15   shirt         7     15
# 1047  RR-924-583       Oyoloo    2019-12-24    book        17     10
# 1048  NM-907-403  Thoughtbeat    2019-08-02  poster         8     26
# 1049  CC-124-201  Thoughtblab    2019-06-30  poster        23      5
#
#       extended amount Company Name     level
# 0                 323     Realcube      gold
# 1                 420        Zooxo  platinum
# 2                 161      Dabtype      gold
# 3                 203     Skipfire      gold
# 4                 684     Bluezoom      gold
# ...               ...          ...       ...
# 1045                0        Quimm      gold
# 1046              105       Podcat    silver
# 1047              170       Oyoloo    silver
# 1048              208  Thoughtbeat    silver
# 1049              115  Thoughtblab      gold
#
# [1050 rows x 9 columns]

# %%
levels.head()
# Out:
#   Company Name     level
# 0        Abatz   diamond
# 1        Agivu    silver
# 2        Aibox  platinum
# 3       Ailane    silver
# 4        Aimbo   diamond

# %%
levels = levels.rename(columns={'Company Name': 'company'})

# %%
levels.head()
# Out:
#   company     level
# 0   Abatz   diamond
# 1   Agivu    silver
# 2   Aibox  platinum
# 3  Ailane    silver
# 4   Aimbo   diamond

# %%
pd.merge(all_sales, levels)
# Out:
#         invoice   company purchase_date product  quantity  price  \
# 0     ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1     ZK-911-48  Realcube    2019-01-31    book        33     35
# 2     CM-131-53  Realcube    2019-12-28  poster        46     35
# 3     TZ-788-30  Realcube    2019-03-07  poster        22     31
# 4     GF-172-18  Realcube    2019-09-07  poster        42     34
# ...         ...       ...           ...     ...       ...    ...
# 1045  UZ-411-71     Zoovu    2019-03-29    book        15     11
# 1046  PZ-354-19   Centizu    2019-04-19     pen         0     27
# 1047  JF-350-29    Voonyx    2019-06-13    book        14     24
# 1048  EH-047-08    Voonyx    2019-11-16     pen        38     13
# 1049  FU-587-89      Omba    2019-09-05    book         9     17
#
#       extended amount     level
# 0                 323      gold
# 1                1155      gold
# 2                1610      gold
# 3                 682      gold
# 4                1428      gold
# ...               ...       ...
# 1045              165  platinum
# 1046                0      gold
# 1047              336  platinum
# 1048              494  platinum
# 1049              153      gold
#
# [1050 rows x 8 columns]

# %%
final_data = pd.merge(all_sales, levels)

# %%
final_data.head()
# Out:
#      invoice   company purchase_date product  quantity  price  \
# 0  ZN-870-29  Realcube    2019-03-05   shirt        19     17
# 1  ZK-911-48  Realcube    2019-01-31    book        33     35
# 2  CM-131-53  Realcube    2019-12-28  poster        46     35
# 3  TZ-788-30  Realcube    2019-03-07  poster        22     31
# 4  GF-172-18  Realcube    2019-09-07  poster        42     34
#
#    extended amount level
# 0              323  gold
# 1             1155  gold
# 2             1610  gold
# 3              682  gold
# 4             1428  gold

# %%
final_data.shape
# Out:
# (1050, 8)

# %%
final_data.tail()
# Out:
#         invoice  company purchase_date product  quantity  price  \
# 1045  UZ-411-71    Zoovu    2019-03-29    book        15     11
# 1046  PZ-354-19  Centizu    2019-04-19     pen         0     27
# 1047  JF-350-29   Voonyx    2019-06-13    book        14     24
# 1048  EH-047-08   Voonyx    2019-11-16     pen        38     13
# 1049  FU-587-89     Omba    2019-09-05    book         9     17
#
#       extended amount     level
# 1045              165  platinum
# 1046                0      gold
# 1047              336  platinum
# 1048              494  platinum
# 1049              153      gold
