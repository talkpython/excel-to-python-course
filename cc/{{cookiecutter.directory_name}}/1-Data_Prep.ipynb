# %% [markdown]
# ## {{cookiecutter.project_name}}
#
# {{cookiecutter.description}}
#
# ### Data Sources
#
# - file 1: Description of location
#
# ### Changes
# - {% now 'utc', '%m-%d-%Y' %} : Started project

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime

# %% [markdown]
# ## File locations

# %% [markdown]
# ## Save output
